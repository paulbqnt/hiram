# %%
from Options import BlackScholes
from yahooquery import Ticker
import pandas as pd
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = BlackScholes(ticker="AAPL", S=100, K=120, r=0.04, sigma=.35, T=12)

# %%
call_price_lst = []

for i in range(1/100,):
    call_price_lst.append(BlackScholes(ticker="AAPL", S=100, K=120, r=i, sigma=.35, T=12).call_value())

plt.plot(call_price_lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 3
#       1 call_price_lst = []
# ----> 3 for i in range(0.01,.5):
#       4     call_price_lst.append(BlackScholes(ticker="AAPL", S=100, K=120, r=i, sigma=.35, T=12).call_value())
#       6 plt.plot(call_price_lst)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
sys.getsizeof(yahoo_object)
# Out:
# 56

# %%
yahoo_object = Ticker(a.ticker)

# %%
yahoo_object.__dir__()
# Out:
# ['_country',
#  '_default_query_params',
#  'formatted',
#  'session',
#  'crumb',
#  'progress',
#  '_symbols',
#  'invalid_symbols',
#  '__module__',
#  '__doc__',
#  '__init__',
#  '_quote_summary',
#  '_quote_summary_dataframe',
#  '_to_dataframe',
#  'all_modules',
#  'get_modules',
#  'asset_profile',
#  'calendar_events',
#  'earnings',
#  'earnings_trend',
#  'esg_scores',
#  'financial_data',
#  'news',
#  'index_trend',
#  'industry_trend',
#  'key_stats',
#  'major_holders',
#  'page_views',
#  'price',
#  'quote_type',
#  'quotes',
#  'recommendations',
#  'share_purchase_activity',
#  'summary_detail',
#  'summary_profile',
#  'technical_insights',
#  '_financials',
#  '_financials_dataframes',
#  'all_financial_data',
#  'get_financial_data',
#  'corporate_events',
#  'corporate_guidance',
#  'valuation_measures',
#  'balance_sheet',
#  'cash_flow',
#  'company_officers',
#  'earning_history',
#  'fund_ownership',
#  'grading_history',
#  'income_statement',
# ...
